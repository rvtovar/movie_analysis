# %% [markdown]
# ### Rose Tovar
# ### Movie Analysis Project
# ### RoseATovar@gmail.com

# %%
import pandas as pd
import numpy as np
import os, json, time
from tqdm.notebook import tqdm_notebook
import tmdbsimple as tmdb

# %%
#urls
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'

# %%
# creating dataframes
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9273132 entries, 0 to 9273131
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 636.7+ MB

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1914
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1720
# 3  tt0000004            5.6       172
# 4  tt0000005            6.2      2536

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1263406 entries, 0 to 1263405
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1263406 non-null  object
#  1   averageRating  1263406 non-null  float64
#  2   numVotes       1263406 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.9+ MB

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
akas.head()
# Out:
#      titleId  ordering                      title region language types  \
# 0  tt0000001         1                 Карменсіта     UA       \N    \N
# 1  tt0000001         2                 Carmencita     DE       \N    \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N    \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N    \N
# 4  tt0000001         5                 Карменсита     RU       \N    \N
#
#   attributes isOriginalTitle
# 0         \N               0
# 1         \N               0
# 2         \N               0
# 3         \N               0
# 4         \N               0

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33383949 entries, 0 to 33383948
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ GB

# %% [markdown]
# ### Specifications

# %%
# excluding movies with missing values for genre or runtime

basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
# removing rows with missing genres and runtimeminutes
basics = basics.dropna(subset=['genres','runtimeMinutes'])
basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres             0
# dtype: int64

# %%
basics.replace('\\N', np.nan, inplace=True)

# %%
# including only full movies
basics = basics.loc[basics['titleType'] == 'movie']
basics['titleType'].value_counts()
# Out:
# movie    622997
# Name: titleType, dtype: int64

# %%
# Removing Documnetary 
basics = basics[basics["genres"].str.contains("Documentary", case=False) == False]
basics['genres'].value_counts()
# Out:
# Drama                         115700
# Comedy                         44384
# Horror                         15536
# Action                         14203
# Thriller                       13975
#                                ...
# Animation,Music,Romance            1
# Action,Comedy,Short                1
# Action,Animation,Game-Show         1
# Biography,Mystery,Romance          1
# News,Sport,Talk-Show               1
# Name: genres, Length: 1233, dtype: int64

# %%
# removing years before 2000 and after 2021
basics['startYear'].value_counts()
# Out:
# 2018    12233
# 2019    11840
# 2017    11789
# 2022    11733
# 2021    11673
#         ...
# 1905        3
# 1906        3
# 2028        2
# 1903        2
# 1894        1
# Name: startYear, Length: 126, dtype: int64

# %%
#dropping nana
basics.dropna(subset=['startYear'],inplace=True)
basics['startYear'].isna().sum()
# Out:
# 0

# %%
#converting to int
basics['startYear'] = basics['startYear'].astype(int)

# %%
#only having movies from 2000 to 2021
basics = basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 34792  tt0035423     movie                                     Kate & Leopold
# 61094  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67640  tt0069049     movie                         The Other Side of the Wind
# 77934  tt0079644     movie                                      November 1828
#
#                                    originalTitle isAdult  startYear endYear  \
# 11636                           Tötet nicht mehr       0       2019     NaN
# 34792                             Kate & Leopold       0       2001     NaN
# 61094  El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67640                 The Other Side of the Wind       0       2018     NaN
# 77934                              November 1828       0       2001     NaN
#
#       runtimeMinutes                  genres
# 11636            NaN            Action,Crime
# 34792            118  Comedy,Fantasy,Romance
# 61094             70                   Drama
# 67640            122                   Drama
# 77934            140               Drama,War

# %%
#replace \N with np.nan in akas and ratings
akas.replace('\\N', np.nan, inplace=True)
ratings.replace('\\N', np.nan, inplace=True)

# %%
# Only movies from United States
akas = akas.loc[akas['region'] == 'US']

# %%
# Updating other dataframes to contain only the same values

basics = basics[basics['tconst'].isin(akas['titleId'])]

# %% [markdown]
# ### Looking at Each Dataframe

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1914
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1720
# 3  tt0000004            5.6       172
# 4  tt0000005            6.2      2536

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34792  tt0035423     movie                                     Kate & Leopold
# 61094  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67640  tt0069049     movie                         The Other Side of the Wind
# 86771  tt0088751     movie                                  The Naked Monster
# 93907  tt0096056     movie                               Crime and Punishment
#
#                                    originalTitle isAdult  startYear endYear  \
# 34792                             Kate & Leopold       0       2001     NaN
# 61094  El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67640                 The Other Side of the Wind       0       2018     NaN
# 86771                          The Naked Monster       0       2005     NaN
# 93907                       Crime and Punishment       0       2002     NaN
#
#       runtimeMinutes                  genres
# 34792            118  Comedy,Fantasy,Romance
# 61094             70                   Drama
# 67640            122                   Drama
# 86771            100    Comedy,Horror,Sci-Fi
# 93907            126                   Drama

# %%
akas.head()
# Out:
#       titleId  ordering                   title region language  types  \
# 5   tt0000001         6              Carmencita     US      NaN    NaN
# 14  tt0000002         7  The Clown and His Dogs     US      NaN    NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN    NaN
# 36  tt0000005         1     Blacksmithing Scene     US      NaN    NaN
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN    NaN
#
#     attributes isOriginalTitle
# 5          NaN               0
# 14         NaN               0
# 33         NaN               0
# 36         NaN               0
# 41         NaN               0

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1263406 entries, 0 to 1263405
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1263406 non-null  object
#  1   averageRating  1263406 non-null  float64
#  2   numVotes       1263406 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.9+ MB

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92072 entries, 34792 to 9272929
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          92072 non-null  object
#  1   titleType       92072 non-null  object
#  2   primaryTitle    92072 non-null  object
#  3   originalTitle   92072 non-null  object
#  4   isAdult         92072 non-null  object
#  5   startYear       92072 non-null  int64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  79708 non-null  object
#  8   genres          92072 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 7.0+ MB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1355882 entries, 5 to 33383693
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1355882 non-null  object
#  1   ordering         1355882 non-null  int64
#  2   title            1355882 non-null  object
#  3   region           1355882 non-null  object
#  4   language         3696 non-null     object
#  5   types            0 non-null        float64
#  6   attributes       0 non-null        float64
#  7   isOriginalTitle  1354507 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 93.1+ MB

# %%
os.makedirs('Data/', exist_ok=True)
os.listdir('Data/')
# Out:
# ['final_tmdb_data_2008.csv.gz',
#  'tmdb_api_results_2013.json',
#  'final_tmdb_data_2000.csv.gz',
#  'title_ratings.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'tmdb_api_results_2009.json',
#  '.ipynb_checkpoints',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2007.json',
#  'updated_basics.csv.gz',
#  'movie_genre.csv.gz',
#  'title_basics.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'tmdb_api_results_2000.json',
#  'updated_tmdb.csv.gz',
#  'tmdb_api_results_2002.json',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2005.json',
#  'final_tmdb_data_2010.csv.gz',
#  'genre_lookup.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'tmdb_api_results_2010.json',
#  'final_tmdb_data_2001.csv.gz',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2005.csv.gz',
#  'tmdb_api_results_2003.json',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'title_akas.csv.gz',
#  'tmdb_results_combined.csv.gz',
#  'tmdb_api_results_2012.json',
#  'final_tmdb_data_2007.csv.gz']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("./Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0           118.0  Comedy,Fantasy,Romance
# 1            70.0                   Drama
# 2           122.0                   Drama
# 3           100.0    Comedy,Horror,Sci-Fi
# 4           126.0                   Drama

# %%
# Open saved file and preview again
ratings = pd.read_csv("./Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1914
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1720
# 3  tt0000004            5.6       172
# 4  tt0000005            6.2      2536

# %%
# Open saved file and preview again
akas = pd.read_csv("./Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language  types  \
# 0  tt0000001         6              Carmencita     US      NaN    NaN
# 1  tt0000002         7  The Clown and His Dogs     US      NaN    NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN    NaN
# 3  tt0000005         1     Blacksmithing Scene     US      NaN    NaN
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN    NaN
#
#    attributes  isOriginalTitle
# 0         NaN              0.0
# 1         NaN              0.0
# 2         NaN              0.0
# 3         NaN              0.0
# 4         NaN              0.0

# %% [markdown]
# ### Loging into TMDB API

# %%
with open('/home/vanica/.secret/tmdb_api.json') as f:
    login = json.load(f)
    
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = login['api-key']

# %% [markdown]
# ### Helper Methods

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
def get_movie_with_rating(id):
    movie = tmdb.Movies(id)
    
    info = movie.info()
    
    releases = movie.releases()
    
    for c in releases['countries']:
        if c['iso_3166_1'] == "US":
            info['certifcation'] = c['certification']
            
    return info

# %% [markdown]
# ### Testing Methods

# %%
avengers = get_movie_with_rating('tt0848228')
notebook = get_movie_with_rating('tt0332280')

# %%
avengers
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 203.325,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.706,
#  'vote_count': 27566,
#  'certifcation': 'PG-13'}

# %%
notebook
# Out:
# {'adult': False,
#  'backdrop_path': '/qom1SZSENdmHFNZBXbtJAU0WTlC.jpg',
#  'belongs_to_collection': None,
#  'budget': 29000000,
#  'genres': [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.newline.com/properties/notebookthe.html',
#  'id': 11036,
#  'imdb_id': 'tt0332280',
#  'original_language': 'en',
#  'original_title': 'The Notebook',
#  'overview': "An epic love story centered around an older man who reads aloud to a woman with Alzheimer's. From a faded notebook, the old man's words bring to life the story about a couple who is separated by World War II, and is then passionately reunited, seven years later, after they have taken different paths.",
#  'popularity': 71.359,
#  'poster_path': '/rNzQyW4f8B8cQeg7Dgj3n6eT5k9.jpg',
#  'production_companies': [{'id': 12,
#    'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png',
#    'name': 'New Line Cinema',
#    'origin_country': 'US'},
#   {'id': 1565, 'logo_path': None, 'name': 'Avery Pix', 'origin_country': 'US'},
#   {'id': 2605,
#    'logo_path': None,
#    'name': 'Gran Via Productions',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2004-06-25',
#  'revenue': 115603229,
#  'runtime': 123,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Behind every great love is a great story.',
#  'title': 'The Notebook',
#  'video': False,
#  'vote_average': 7.879,
#  'vote_count': 9841,
#  'certifcation': 'PG-13'}

# %% [markdown]
# ### Make data directory

# %%
FOLDER = 'Data/'
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['final_tmdb_data_2008.csv.gz',
#  'tmdb_api_results_2013.json',
#  'final_tmdb_data_2000.csv.gz',
#  'title_ratings.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'tmdb_api_results_2009.json',
#  '.ipynb_checkpoints',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2007.json',
#  'updated_basics.csv.gz',
#  'movie_genre.csv.gz',
#  'title_basics.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'tmdb_api_results_2000.json',
#  'updated_tmdb.csv.gz',
#  'tmdb_api_results_2002.json',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2005.json',
#  'final_tmdb_data_2010.csv.gz',
#  'genre_lookup.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'tmdb_api_results_2010.json',
#  'final_tmdb_data_2001.csv.gz',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2005.csv.gz',
#  'tmdb_api_results_2003.json',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'title_akas.csv.gz',
#  'tmdb_results_combined.csv.gz',
#  'tmdb_api_results_2012.json',
#  'final_tmdb_data_2007.csv.gz']

# %% [markdown]
# ### Read in Basics Data

# %%
# Open saved file and preview again
basics = pd.read_csv("./Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0           118.0  Comedy,Fantasy,Romance
# 1            70.0                   Drama
# 2           122.0                   Drama
# 3           100.0    Comedy,Horror,Sci-Fi
# 4           126.0                   Drama

# %% [markdown]
# ### Setting up years to get and errors array

# %%
YEARS_TO_GET = list(range(2014,2023))
errors = [ ]

# %%
##### Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    # If it does not exist: create it
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    file_exists = os.path.isfile(JSON_FILE)

    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)

    df = basics.loc[basics['startYear'] == YEAR].copy()
    movie_ids = df['tconst'].copy()
    
    prev_df = pd.read_json(JSON_FILE)
    
    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(prev_df['imdb_id'])]

        #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            errors.append([movie_id, e])

    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)

print(f"- Total errors: {len(errors)}")
# Out:
# YEARS:   0%|          | 0/9 [00:00<?, ?it/s]
# Movies from 2014:   0%|          | 0/5407 [00:00<?, ?it/s]
# Movies from 2015:   0%|          | 0/5621 [00:00<?, ?it/s]
# Movies from 2016:   0%|          | 0/6051 [00:00<?, ?it/s]
# Movies from 2017:   0%|          | 0/6471 [00:00<?, ?it/s]
# Movies from 2018:   0%|          | 0/6656 [00:00<?, ?it/s]
# Movies from 2019:   0%|          | 0/6659 [00:00<?, ?it/s]
# Movies from 2020:   0%|          | 0/6047 [00:00<?, ?it/s]
# Movies from 2021:   0%|          | 0/6413 [00:00<?, ?it/s]
# Movies from 2022: 0it [00:00, ?it/s]
# - Total errors: 15473

# %%
movies00 = pd.read_csv("./Data/final_tmdb_data_2000.csv.gz", low_memory = False)
movies00.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# 0                                   NaN       NaN               NaN
# 1                                   NaN   62127.0                en
# 2                                   NaN  110977.0                en
# 3                                   NaN  442869.0                hi
# 4  http://www.wkw-inthemoodforlove.com/     843.0                cn
#
#     original_title  ...     revenue  runtime  \
# 0              NaN  ...         NaN      NaN
# 1  The Fantasticks  ...         0.0     86.0
# 2    For the Cause  ...         0.0    100.0
# 3             Gang  ...         0.0    152.0
# 4             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certifcation
# 0    NaN           NaN        NaN          NaN
# 1    0.0         5.500       22.0          NaN
# 2    0.0         5.100        8.0          NaN
# 3    0.0         0.000        0.0          NaN
# 4    0.0         8.111     1979.0           PG
#
# [5 rows x 26 columns]

# %%
movies01 = pd.read_csv("./Data/final_tmdb_data_2001.csv.gz", low_memory = False)
movies01.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'Italian', 'iso_639_1': 'it'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century they'd be pe...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certifcation
# 0    NaN           NaN        NaN          NaN
# 1    0.0           6.3     1141.0        PG-13
# 2    0.0           5.0        3.0          NaN
# 3    0.0           4.6      117.0        PG-13
# 4    0.0           5.1       28.0            R
#
# [5 rows x 26 columns]
